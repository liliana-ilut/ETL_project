# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### 1. Extract CSVs into DataFrames

# %%
covid_csv = "Resources/covid19.csv"
covid_data_df = pd.read_csv(covid_csv)
covid_data_df
# Out:
#                    country  total_cases new_cases  total_deaths  new_deaths  \
# 0            United States      1621196       294         96359           5
# 1                   Russia       326448      8894          3249         150
# 2                   Brazil       310921         0         20082           0
# 3                    Spain       280117         0         27940           0
# 4           United Kingdom       250908         0         36042           0
# ..                     ...          ...       ...           ...         ...
# 208              St. Barth            6         0             0           0
# 209         Western Sahara            6         0             0           0
# 210               Anguilla            3         0             0           0
# 211                Lesotho            1         0             0           0
# 212  Saint Pierre Miquelon            1         0             0           0
#
#      total_recovered  active_cases  active_critical  total_tests  population
# 0             382244       1142593            17907     13479242   330790544
# 1              99825        223374             2300      8126626   145927804
# 2             125960        164879             8318       735224   212393298
# 3             196958         55219             1152      3037840    46752851
# 4               1918        212948             1559      3090566    67847158
# ..               ...           ...              ...          ...         ...
# 208                6             0                0            0        9874
# 209                6             0                0            0      595583
# 210                3             0                0            0       14988
# 211                0             1                0            0     2140374
# 212                1             0                0            0        5797
#
# [213 rows x 10 columns]

# %%
happiness_csv = "Resources/happiness.csv"
happiness_data_df = pd.read_csv(happiness_csv)
happiness_data_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %% [markdown]
# ### 2. Transform DataFrame

# %% [markdown]
# #### 2.a. Transform covid19 DataFrame

# %%
# # drop all colomns that we do not need
reduced_covid_data_df = covid_data_df [["country", "total_cases", "total_deaths","total_recovered", "total_tests", "population" ]]
reduced_covid_data_df
# Out:
#                    country  total_cases  total_deaths  total_recovered  \
# 0            United States      1621196         96359           382244
# 1                   Russia       326448          3249            99825
# 2                   Brazil       310921         20082           125960
# 3                    Spain       280117         27940           196958
# 4           United Kingdom       250908         36042             1918
# ..                     ...          ...           ...              ...
# 208              St. Barth            6             0                6
# 209         Western Sahara            6             0                6
# 210               Anguilla            3             0                3
# 211                Lesotho            1             0                0
# 212  Saint Pierre Miquelon            1             0                1
#
#      total_tests  population
# 0       13479242   330790544
# 1        8126626   145927804
# 2         735224   212393298
# 3        3037840    46752851
# 4        3090566    67847158
# ..           ...         ...
# 208            0        9874
# 209            0      595583
# 210            0       14988
# 211            0     2140374
# 212            0        5797
#
# [213 rows x 6 columns]

# %%
# rename the colomns
renamed_covid_data_df = reduced_covid_data_df.rename(columns={
                                        "country": "Country or region",
                                        "total_cases": "Total Cases",
                                        "total_deaths": "Total Deaths",
                                        "total_recovered": "Total Recovered",
                                        "total_tests": "Total Tests",
                                        "population": "Population"
                                        
                        })
renamed_covid_data_df
# Out:
#          Country or region  Total Cases  Total Deaths  Total Recovered  \
# 0            United States      1621196         96359           382244
# 1                   Russia       326448          3249            99825
# 2                   Brazil       310921         20082           125960
# 3                    Spain       280117         27940           196958
# 4           United Kingdom       250908         36042             1918
# ..                     ...          ...           ...              ...
# 208              St. Barth            6             0                6
# 209         Western Sahara            6             0                6
# 210               Anguilla            3             0                3
# 211                Lesotho            1             0                0
# 212  Saint Pierre Miquelon            1             0                1
#
#      Total Tests  Population
# 0       13479242   330790544
# 1        8126626   145927804
# 2         735224   212393298
# 3        3037840    46752851
# 4        3090566    67847158
# ..           ...         ...
# 208            0        9874
# 209            0      595583
# 210            0       14988
# 211            0     2140374
# 212            0        5797
#
# [213 rows x 6 columns]

# %% [markdown]
# #### 2.b. Transform happiness DataFrame

# %%
# # drop all colomns that we do not need
reduced_happiness_data_df = happiness_data_df [["Country or region", "Overall rank", "Score","GDP per capita", "Healthy life expectancy" ]]
reduced_happiness_data_df
# Out:
#             Country or region  Overall rank  Score  GDP per capita  \
# 0                     Finland             1  7.769           1.340
# 1                     Denmark             2  7.600           1.383
# 2                      Norway             3  7.554           1.488
# 3                     Iceland             4  7.494           1.380
# 4                 Netherlands             5  7.488           1.396
# ..                        ...           ...    ...             ...
# 151                    Rwanda           152  3.334           0.359
# 152                  Tanzania           153  3.231           0.476
# 153               Afghanistan           154  3.203           0.350
# 154  Central African Republic           155  3.083           0.026
# 155               South Sudan           156  2.853           0.306
#
#      Healthy life expectancy
# 0                      0.986
# 1                      0.996
# 2                      1.028
# 3                      1.026
# 4                      0.999
# ..                       ...
# 151                    0.614
# 152                    0.499
# 153                    0.361
# 154                    0.105
# 155                    0.295
#
# [156 rows x 5 columns]

# %% [markdown]
# #### 2.c. Merge the 2 data sets

# %%
#merge happiness and covid data sets into a new "combined_data_df"
combined_data_df = pd.merge(reduced_happiness_data_df,renamed_covid_data_df, on ="Country or region", how = "inner")
combined_data_df
# Out:
#     Country or region  Overall rank  Score  GDP per capita  \
# 0             Finland             1  7.769           1.340
# 1             Denmark             2  7.600           1.383
# 2              Norway             3  7.554           1.488
# 3             Iceland             4  7.494           1.380
# 4         Netherlands             5  7.488           1.396
# ..                ...           ...    ...             ...
# 141             Yemen           151  3.380           0.287
# 142            Rwanda           152  3.334           0.359
# 143          Tanzania           153  3.231           0.476
# 144       Afghanistan           154  3.203           0.350
# 145       South Sudan           156  2.853           0.306
#
#      Healthy life expectancy  Total Cases  Total Deaths  Total Recovered  \
# 0                      0.986         6493           306             4800
# 1                      0.996        11182           561             9643
# 2                      1.028         8309           235               32
# 3                      1.026         1803            10             1790
# 4                      0.999        44700          5775             3459
# ..                       ...          ...           ...              ...
# 141                    0.463          197            33                5
# 142                    0.614          320             0              217
# 143                    0.499          509            21              183
# 144                    0.361         9216           205              996
# 145                    0.295          481             4                4
#
#      Total Tests  Population
# 0         160177     5539799
# 1         504266     5789998
# 2         223045     5416564
# 3          58225      341000
# 4         302395    17130802
# ..           ...         ...
# 141          120    29748378
# 142        54400    12913795
# 143            0    59527001
# 144        27889    38824552
# 145         3356    11178970
#
# [146 rows x 10 columns]

# %%
#set the index on the file to the overall happiness rank
combined_data_df = combined_data_df.rename(columns={"Overall rank": "overall_rank"})
combined_data_df
# Out:
#     Country or region  overall_rank  Score  GDP per capita  \
# 0             Finland             1  7.769           1.340
# 1             Denmark             2  7.600           1.383
# 2              Norway             3  7.554           1.488
# 3             Iceland             4  7.494           1.380
# 4         Netherlands             5  7.488           1.396
# ..                ...           ...    ...             ...
# 141             Yemen           151  3.380           0.287
# 142            Rwanda           152  3.334           0.359
# 143          Tanzania           153  3.231           0.476
# 144       Afghanistan           154  3.203           0.350
# 145       South Sudan           156  2.853           0.306
#
#      Healthy life expectancy  Total Cases  Total Deaths  Total Recovered  \
# 0                      0.986         6493           306             4800
# 1                      0.996        11182           561             9643
# 2                      1.028         8309           235               32
# 3                      1.026         1803            10             1790
# 4                      0.999        44700          5775             3459
# ..                       ...          ...           ...              ...
# 141                    0.463          197            33                5
# 142                    0.614          320             0              217
# 143                    0.499          509            21              183
# 144                    0.361         9216           205              996
# 145                    0.295          481             4                4
#
#      Total Tests  Population
# 0         160177     5539799
# 1         504266     5789998
# 2         223045     5416564
# 3          58225      341000
# 4         302395    17130802
# ..           ...         ...
# 141          120    29748378
# 142        54400    12913795
# 143            0    59527001
# 144        27889    38824552
# 145         3356    11178970
#
# [146 rows x 10 columns]

# %%
combined_data_df.set_index('overall_rank', inplace=True)
combined_data_df
# Out:
#              Country or region  Score  GDP per capita  \
# overall_rank
# 1                      Finland  7.769           1.340
# 2                      Denmark  7.600           1.383
# 3                       Norway  7.554           1.488
# 4                      Iceland  7.494           1.380
# 5                  Netherlands  7.488           1.396
# ...                        ...    ...             ...
# 151                      Yemen  3.380           0.287
# 152                     Rwanda  3.334           0.359
# 153                   Tanzania  3.231           0.476
# 154                Afghanistan  3.203           0.350
# 156                South Sudan  2.853           0.306
#
#               Healthy life expectancy  Total Cases  Total Deaths  \
# overall_rank
# 1                               0.986         6493           306
# 2                               0.996        11182           561
# 3                               1.028         8309           235
# 4                               1.026         1803            10
# 5                               0.999        44700          5775
# ...                               ...          ...           ...
# 151                             0.463          197            33
# 152                             0.614          320             0
# 153                             0.499          509            21
# 154                             0.361         9216           205
# 156                             0.295          481             4
#
#               Total Recovered  Total Tests  Population
# overall_rank
# 1                        4800       160177     5539799
# 2                        9643       504266     5789998
# 3                          32       223045     5416564
# 4                        1790        58225      341000
# 5                        3459       302395    17130802
# ...                       ...          ...         ...
# 151                         5          120    29748378
# 152                       217        54400    12913795
# 153                       183            0    59527001
# 154                       996        27889    38824552
# 156                         4         3356    11178970
#
# [146 rows x 9 columns]

# %%
# round all the numbers to only 2 decimals
final_merged_df =combined_data_df.round(2)
final_merged_df
# Out:
#              Country or region  Score  GDP per capita  \
# overall_rank
# 1                      Finland   7.77            1.34
# 2                      Denmark   7.60            1.38
# 3                       Norway   7.55            1.49
# 4                      Iceland   7.49            1.38
# 5                  Netherlands   7.49            1.40
# ...                        ...    ...             ...
# 151                      Yemen   3.38            0.29
# 152                     Rwanda   3.33            0.36
# 153                   Tanzania   3.23            0.48
# 154                Afghanistan   3.20            0.35
# 156                South Sudan   2.85            0.31
#
#               Healthy life expectancy  Total Cases  Total Deaths  \
# overall_rank
# 1                                0.99         6493           306
# 2                                1.00        11182           561
# 3                                1.03         8309           235
# 4                                1.03         1803            10
# 5                                1.00        44700          5775
# ...                               ...          ...           ...
# 151                              0.46          197            33
# 152                              0.61          320             0
# 153                              0.50          509            21
# 154                              0.36         9216           205
# 156                              0.30          481             4
#
#               Total Recovered  Total Tests  Population
# overall_rank
# 1                        4800       160177     5539799
# 2                        9643       504266     5789998
# 3                          32       223045     5416564
# 4                        1790        58225      341000
# 5                        3459       302395    17130802
# ...                       ...          ...         ...
# 151                         5          120    29748378
# 152                       217        54400    12913795
# 153                       183            0    59527001
# 154                       996        27889    38824552
# 156                         4         3356    11178970
#
# [146 rows x 9 columns]

# %%
final_merged_df = final_merged_df.rename(columns={
                                        "Country or region": "country_or_region",
                                        "Score":"score",
                                        "GDP per capita": "gdp_per_capita",
                                        "Healthy life expectancy": "healthy_life_expectancy",
                                        "Total Cases": "total_cases",
                                        "Total Deaths": "total_deaths",
                                        "Total Recovered": "total_recovered",
                                        "Total Tests": "total_tests",
                                        "Population": "population"
                                        
                        })
final_merged_df
# Out:
#              country_or_region  score  gdp_per_capita  \
# overall_rank
# 1                      Finland   7.77            1.34
# 2                      Denmark   7.60            1.38
# 3                       Norway   7.55            1.49
# 4                      Iceland   7.49            1.38
# 5                  Netherlands   7.49            1.40
# ...                        ...    ...             ...
# 151                      Yemen   3.38            0.29
# 152                     Rwanda   3.33            0.36
# 153                   Tanzania   3.23            0.48
# 154                Afghanistan   3.20            0.35
# 156                South Sudan   2.85            0.31
#
#               healthy_life_expectancy  total_cases  total_deaths  \
# overall_rank
# 1                                0.99         6493           306
# 2                                1.00        11182           561
# 3                                1.03         8309           235
# 4                                1.03         1803            10
# 5                                1.00        44700          5775
# ...                               ...          ...           ...
# 151                              0.46          197            33
# 152                              0.61          320             0
# 153                              0.50          509            21
# 154                              0.36         9216           205
# 156                              0.30          481             4
#
#               total_recovered  total_tests  population
# overall_rank
# 1                        4800       160177     5539799
# 2                        9643       504266     5789998
# 3                          32       223045     5416564
# 4                        1790        58225      341000
# 5                        3459       302395    17130802
# ...                       ...          ...         ...
# 151                         5          120    29748378
# 152                       217        54400    12913795
# 153                       183            0    59527001
# 154                       996        27889    38824552
# 156                         4         3356    11178970
#
# [146 rows x 9 columns]

# %%
# export the new file to a csv file, called "combined.cs"
final_merged_df.to_csv("combined.csv")

# %% [markdown]
# ### 3. Load

# %%
### Connect to local database

#import dependencies
from sqlalchemy.ext.automap import automap_base
from config import password

engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/happycovid')

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
